# %% [markdown]
# <a href="https://colab.research.google.com/github/e23046/Statistical-Learning-e23046/blob/main/Assignment%201/Q2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Geometric Setup
#
# Let's define a circle with radius `R` centered at the origin (0,0). We will also consider an equilateral triangle inscribed within this circle.

# %% [markdown]
# **Reasoning**:
# Now that the geometric setup is defined, I will calculate the side length of an equilateral triangle inscribed in a circle of radius R. This involves a known geometric formula.

# %%
import sympy

R = sympy.Symbol('R')

# For an equilateral triangle inscribed in a circle, the side length 's' is given by s = R * sqrt(3).
s = R * sympy.sqrt(3)

print(f"The side length of an equilateral triangle inscribed in a circle of radius R is: s = {s}")
# Out:
# The side length of an equilateral triangle inscribed in a circle of radius R is: s = sqrt(3)*R

# %% [markdown]
# ### Condition for Chord Length Exceeding Inscribed Triangle Side Length
#
# Let `L` be the length of a chord and `s` be the side length of the inscribed equilateral triangle, which we found to be `s = R * sqrt(3)`. We want to find the condition where `L > s`.
#
# The length of a chord `L` in a circle of radius `R` is related to its distance `d` from the center by the formula: `L = 2 * sqrt(R^2 - d^2)`.
#
# So, the condition `L > s` becomes:
# `2 * sqrt(R^2 - d^2) > R * sqrt(3)`
#
# To solve for `d`, we square both sides:
# `4 * (R^2 - d^2) > 3 * R^2`
# `4R^2 - 4d^2 > 3R^2`
# `R^2 > 4d^2`
# Taking the square root of both sides (and considering `d` is a non-negative distance):
# `R > 2d`
# `d < R/2`
#
# Therefore, a randomly selected chord will have a length greater than the side length of the inscribed equilateral triangle if and only if its perpendicular distance from the center of the circle is less than `R/2`.

# %% [markdown]
# # Task
# Explain Bertrand's Paradox by demonstrating three different methods for randomly selecting a chord in a circle, calculating the probability that the chord's length exceeds the side of an inscribed equilateral triangle for each method, and discussing how these varying probabilities illustrate the paradox.

# %% [markdown]
# ## Understand the Problem Setup
#
# ### Subtask:
# Establish the geometric setup: a circle and an inscribed equilateral triangle. Define the condition for a chord's length to exceed the side length of the inscribed equilateral triangle.

# %% [markdown]
# ## Method 1: Random Endpoints on the Circumference
#
# ### Subtask:
# Describe and calculate the probability using the method where two random points are chosen independently on the circumference of the circle to define the chord.

# %% [markdown]
# ### Method 1: Random Endpoints on the Circumference
#
# To define a chord using this method, we select two points, $P_1$ and $P_2$, independently and uniformly at random on the circumference of a circle with radius $R$. The line segment connecting $P_1$ and $P_2$ forms the chord. Our goal is to determine the probability that the length of this chord, $L$, is greater than the side length of an inscribed equilateral triangle, $s = R\sqrt{3}$.
#
# Let's fix one point, $P_1$, at an arbitrary position on the circumference. Without loss of generality, we can place $P_1$ at the top of the circle (e.g., at coordinates $(0, R)$ if the circle is centered at the origin). The position of the second point, $P_2$, can then be described by its angular separation from $P_1$. Let this angular separation be $\theta$, where $\theta$ ranges from $0$ to $2\pi$ radians.
#
# The length of a chord in a circle of radius $R$ is given by the formula $L = 2R \sin(\frac{\theta}{2})$.
#
# We need to find the values of $\theta$ for which $L > s$, i.e., $2R \sin(\frac{\theta}{2}) > R\sqrt{3}$.
#
# Dividing by $2R$ (since $R > 0$):
# $\sin(\frac{\theta}{2}) > \frac{\sqrt{3}}{2}$
#
# The general solutions for $\sin(x) = \frac{\sqrt{3}}{2}$ are $x = \frac{\pi}{3}$ and $x = \frac{2\pi}{3}$.
#
# So, we need $\frac{\pi}{3} < \frac{\theta}{2} < \frac{2\pi}{3}$.
#
# Multiplying by 2:
# $\frac{2\pi}{3} < \theta < \frac{4\pi}{3}$
#
# This means that for the chord length to be greater than $s$, the angular separation $\theta$ between $P_1$ and $P_2$ must be between $2\pi/3$ (120 degrees) and $4\pi/3$ (240 degrees). The total possible range for $\theta$ is $2\pi$ (from $0$ to $2\pi$).
#
# The favorable range for $\theta$ is $4\pi/3 - 2\pi/3 = 2\pi/3$.
#
# Therefore, the probability is the ratio of the favorable angular range to the total angular range:
#
# $P = \frac{2\pi/3}{2\pi}$

# %% [markdown]
# $P = \frac{2\pi/3}{2\pi} = \frac{1}{3}$
#
# Thus, for Method 1, the probability that a randomly chosen chord is longer than the side of an inscribed equilateral triangle is $\frac{1}{3}$.

# %% [markdown]
# $P = \frac{2\pi/3}{2\pi} = \frac{1}{3}$
#
# Thus, for Method 1, the probability that a randomly chosen chord is longer than the side of an inscribed equilateral triangle is $\frac{1}{3}$.

# %% [markdown]
# $P = \frac{2\pi/3}{2\pi} = \frac{1}{3}$
#
# Thus, for Method 1, the probability that a randomly chosen chord is longer than the side of an inscribed equilateral triangle is $\frac{1}{3}$.

# %% [markdown]
# $P = \frac{2\pi/3}{2\pi} = \frac{1}{3}$
#
# Thus, for Method 1, the probability that a randomly chosen chord is longer than the side of an inscribed equilateral triangle is $\frac{1}{3}$.

# %% [markdown]
# $P = \frac{2\pi/3}{2\pi} = \frac{1}{3}$
#
# Thus, for Method 1, the probability that a randomly chosen chord is longer than the side of an inscribed equilateral triangle is $\frac{1}{3}$.

# %% [markdown]
# $P = \frac{2\pi/3}{2\pi} = \frac{1}{3}$
#
# Thus, for Method 1, the probability that a randomly chosen chord is longer than the side of an inscribed equilateral triangle is $\frac{1}{3}$.

# %% [markdown]
# ```markdown
# $P = \frac{2\pi/3}{2\pi} = \frac{1}{3}$
#
# Thus, for Method 1, the probability that a randomly chosen chord is longer than the side of an inscribed equilateral triangle is $\frac{1}{3}$.
# ```

# %% [markdown]
# ## Method 2: Random Radial Point
#
# ### Subtask:
# Describe and calculate the probability using the method where a random point is chosen along a radius, and a chord is drawn perpendicular to that radius through the point.

# %% [markdown]
# ### Description of Method 2: Random Radial Point
#
# In this method, we select a random point along a radius of the circle. A chord is then drawn perpendicular to this radius, passing through the chosen point.
#
# Let `r` be the distance of the chosen point from the center of the circle. The chord's length `L` is related to `R` (radius of the circle) and `r` by the formula `L = 2 * sqrt(R^2 - r^2)`.
#
# From our 'Understand the Problem Setup' phase, we know that a chord's length `L` exceeds the side length of an inscribed equilateral triangle `s = R * sqrt(3)` if its distance from the center `r` is less than `R/2`.

# %% [markdown]
# ### Probability Calculation for Method 2
#
# For a chord's length `L` to be greater than the side length `s = R * sqrt(3)` of the inscribed equilateral triangle, its distance `r` from the center must satisfy `r < R/2`.
#
# In this method, `r` is chosen randomly along a radius. The radius extends from `r = 0` (the center) to `r = R` (the circumference). Therefore, the possible values for `r` range from `0` to `R`.
#
# The favorable range for `r` is `0 <= r < R/2`.
#
# The total range for `r` is `0 <= r <= R`.
#
# The probability is the ratio of the favorable length of the radius to the total length of the radius:
#
# `Probability = (Favorable length) / (Total length) = (R/2 - 0) / (R - 0) = (R/2) / R = 1/2`
#
# Thus, the probability that a randomly chosen chord (using the random radial point method) has a length greater than the side of the inscribed equilateral triangle is **1/2**.

# %% [markdown]
# ## Method 3: Random Midpoint
#
# ### Subtask:
# Describe and calculate the probability using the method where a random point is chosen within the circle, and this point is taken as the midpoint of the chord.

# %% [markdown]
# ### Description of the Random Midpoint Method
#
# In this method, a random point is chosen uniformly within the entire area of the circle. This chosen point serves as the midpoint of the chord. The chord is then constructed perpendicular to the radius passing through this midpoint. If the chosen midpoint is at the center of the circle, the chord will be a diameter.
#
# ### Condition for Chord Length
#
# We previously established that for a chord's length to exceed the side length of an inscribed equilateral triangle, its distance `d` from the center of the circle must be less than `R/2`. The side length of the inscribed equilateral triangle is `s = R * sqrt(3)`. A chord of length `L` at a distance `d` from the center in a circle of radius `R` satisfies the relationship `(L/2)^2 + d^2 = R^2`. For the chord to be longer than `s`, we need `L > R * sqrt(3)`. This implies `(R * sqrt(3) / 2)^2 + d^2 < R^2`, which simplifies to `3R^2/4 + d^2 < R^2`, or `d^2 < R^2/4`, leading to `d < R/2`.

# %% [markdown]
# ### Determining Favorable Area and Total Sample Space
#
# For a chord's length to be greater than the side length of the inscribed equilateral triangle, its midpoint must lie within a concentric circle of radius `R/2`. This region represents the **favorable area**.
#
# The **total sample space** for the midpoint is the entire circle, which has a radius `R`.
#
# ### Calculating the Probability
#
# The probability is the ratio of the favorable area to the total area:
#
# Probability = (Area of inner circle with radius `R/2`) / (Area of outer circle with radius `R`)
#
# Area of a circle = `π * (radius)^2`

# %% [markdown]
# **Reasoning**:
# The previous steps described the method and the conditions for the chord. Now, I will proceed to explicitly calculate the probability by defining the areas for the favorable outcome and the total sample space.

# %%
import sympy

R = sympy.Symbol('R')

# Area of the outer circle (total sample space)
area_total = sympy.pi * R**2

# Area of the inner circle (favorable area) where the midpoint must lie
# This is a circle with radius R/2
area_favorable = sympy.pi * (R/2)**2

# Calculate the probability
probability = area_favorable / area_total

print(f"The total area for the midpoint (entire circle) is: {area_total}")
print(f"The favorable area for the midpoint (inner circle with radius R/2) is: {area_favorable}")
print(f"The probability that a randomly chosen chord (by midpoint method) is longer than the side of the inscribed equilateral triangle is: {probability}")
# Out:
# The total area for the midpoint (entire circle) is: pi*R**2
# The favorable area for the midpoint (inner circle with radius R/2) is: pi*R**2/4
# The probability that a randomly chosen chord (by midpoint method) is longer than the side of the inscribed equilateral triangle is: 1/4

# %% [markdown]
# ### Summary of Probabilities and Bertrand's Paradox
#
# We have explored three distinct methods for randomly selecting a chord within a circle, and for each method, we calculated the probability that the chord's length exceeds the side length of an inscribed equilateral triangle ($s = R\sqrt{3}$).
#
# 1.  **Method 1: Random Endpoints on the Circumference**
#     *   Probability: $\frac{1}{3}$
#
# 2.  **Method 2: Random Radial Point**
#     *   Probability: $\frac{1}{2}$
#
# 3.  **Method 3: Random Midpoint**
#     *   Probability: $\frac{1}{4}$
#
#
# These widely differing probabilities ($\frac{1}{3}$, $\frac{1}{2}$, and $\frac{1}{4}$) for seemingly the same question illustrate **Bertrand's Paradox**. The paradox highlights the ambiguity inherent in the phrase "randomly selecting a chord" in geometric probability. Without a precise and explicit definition of the random process being used, the term "random" can be interpreted in multiple, equally valid ways, leading to different outcomes.
#
# Each method corresponds to a fundamentally different way of defining what constitutes a "random" chord:
#
# *   **Method 1 (Random Endpoints)** assumes that the *angular position* of the two chord endpoints on the circumference is uniformly random.
# *   **Method 2 (Random Radial Point)** assumes that the *distance of the chord from the center* (along a chosen radius) is uniformly random.
# *   **Method 3 (Random Midpoint)** assumes that the *position of the chord's midpoint within the circle's area* is uniformly random.
#
# The implications of this ambiguity are profound, especially in geometric probability. It demonstrates that the concept of "randomness" is not absolute but depends critically on the underlying sample space and the probability distribution defined over it. To avoid such paradoxes, it is crucial to clearly and unambiguously specify the exact random process being used when posing or solving problems involving random geometric objects. Without such specification, a problem can lead to multiple, mathematically correct, yet numerically different solutions, making the original question ill-posed.

# %% [markdown]
# ## Illustrate and Summarize Paradox
#
# ### Subtask:
# Present the different probabilities obtained from each method and explain how this demonstrates Bertrand's Paradox, highlighting the ambiguity of 'random selection' in geometric probability.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Provide a comprehensive explanation of Bertrand's Paradox, summarizing the results from each method and discussing the implications of ill-defined randomness.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The task asked to explain Bertrand's Paradox by demonstrating three different methods for randomly selecting a chord in a circle, calculating the probability that the chord's length exceeds the side of an inscribed equilateral triangle for each method, and discussing how these varying probabilities illustrate the paradox.
#
# *   **Bertrand's Paradox Explanation:** Bertrand's Paradox demonstrates that the seemingly simple phrase "randomly selecting a chord" is ambiguous in geometric probability. Without a precise definition of the random process and the sample space, different valid interpretations of "random selection" lead to distinct, numerically different probabilities for the same question.
#
# ### Data Analysis Key Findings
# *   The side length of an equilateral triangle inscribed in a circle of radius \$R\$ is \$R\sqrt{3}\$.
# *   A chord's length \$L\$ in a circle exceeds the side length of the inscribed equilateral triangle if and only if its perpendicular distance \$d\$ from the center of the circle is less than \$R/2\$.
# *   **Method 1: Random Endpoints on the Circumference** (two points chosen uniformly and independently on the circumference) yielded a probability of **1/3** that the chord's length exceeds the side of the inscribed equilateral triangle. This method assumes uniform randomness for the angular positions of the endpoints.
# *   **Method 2: Random Radial Point** (a random point chosen along a radius, and a chord drawn perpendicular to that radius through the point) yielded a probability of **1/2**. This method assumes uniform randomness for the distance of the chord from the center along a specific radius.
# *   **Method 3: Random Midpoint** (a random point chosen uniformly within the circle, serving as the chord's midpoint) yielded a probability of **1/4**. This method assumes uniform randomness for the position of the chord's midpoint within the circle's area.
# *   The variance in probabilities (\$_1/3\$, \$1/2\$, \$1/4\$) for the same problem highlights the paradox, emphasizing that the definition of "random" is crucial in geometric probability.
#
# ### Insights or Next Steps
# *   When defining probability problems, especially in geometric contexts, it is critical to unambiguously specify the random process and the underlying sample space to avoid ill-posed questions and paradoxical results.
# *   Further exploration could involve simulating these methods to empirically verify the calculated probabilities, or investigating other geometric probability paradoxes to deepen understanding of the role of measure theory in defining randomness.
